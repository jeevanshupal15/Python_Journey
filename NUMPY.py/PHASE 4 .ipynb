# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr1 = np.array([1, 2, 3, 4, 5])
arr2 = np.random.rand(3,3)
arr3 = np.zeros((4,4))

# %%
np.save('arr1.npy',arr1)
np.save('arr2.npy',arr2)
np.save('arr3.npy',arr3)

# %%
laoded_arr = np.load('arr1.npy')
print("laoded_arr",laoded_arr)
# Out:
# laoded_arr [1 2 3 4 5]

# %%
try:
    logo =plt.imread('image.png')
    #display
    plt.Figure(figsize=(10,5))
    plt.subplot(121)
    plt.imshow(logo)
    plt.title("nummpy logo")
    plt.grid(False)
    # dark logo
    dark_logo = 1-logo
    plt.subplot(122)
    plt.imshow(dark_logo)
    plt.title("dark logo")
    plt.grid(False) 
except FileNotFoundError:
    print("numpy File not found")
